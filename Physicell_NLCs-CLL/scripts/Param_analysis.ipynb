# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Load experimental data

# %%
experimental = np.loadtxt('../../Netlogo_NLCs-CLL/filtered_fused_9patients.csv', delimiter=",", skiprows=1)
viability_exp = experimental[:,1]
concentration_exp = experimental[:,2]
time_points = experimental[:,0]

# %% [markdown]
# ##### Load output from simulation

# %%
viability_data = pd.read_csv('../data_output/Parameter_exploration/viability_exploration.csv', delimiter=",")
concentration_data = pd.read_csv('../data_output/Parameter_exploration/concentration_exploration.csv', delimiter=",")
vals = [0, 1, 3, 5, 7, 9, 10]

# %% [markdown]
# #### Uptake rate cancer

# %%
param_name = "uptake_rate_cancer"

viability = viability_data.iloc[:,0:len(vals)]
concentration = concentration_data.iloc[:,0:len(vals)]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %% [markdown]
# #### Speed cancer

# %%
param_name = "speed_cancer"
viability = viability_data.iloc[:,len(vals):len(vals)*2]
concentration = concentration_data.iloc[:,len(vals):len(vals)*2]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %%
param_name = "transformation_rate_cancer"
viability = viability_data.iloc[:,len(vals)*2:len(vals)*3]
concentration = concentration_data.iloc[:,len(vals)*2:len(vals)*3]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %%
param_name = "speed_monocytes"
viability = viability_data.iloc[:,len(vals)*3:len(vals)*4]
concentration = concentration_data.iloc[:,len(vals)*3:len(vals)*4]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %%
param_name = "dead_phagocytosis_rate_monocytes"
viability = viability_data.iloc[:,len(vals)*4:len(vals)*5]
concentration = concentration_data.iloc[:,len(vals)*4:len(vals)*5]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %%
param_name = "speed_macrophages"
viability = viability_data.iloc[:,len(vals)*5:len(vals)*6]
concentration = concentration_data.iloc[:,len(vals)*5:len(vals)*6]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %%
param_name = "dead_phagocytosis_rate_macrophages"
viability = viability_data.iloc[:,len(vals)*6:len(vals)*7]
concentration = concentration_data.iloc[:,len(vals)*6:len(vals)*7]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %%
param_name = "secretion_rate_NLCs"
viability = viability_data.iloc[:,len(vals)*7:len(vals)*8]
concentration = concentration_data.iloc[:,len(vals)*7:len(vals)*8]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %%
param_name = "speed_NLCs"
viability = viability_data.iloc[:,len(vals)*8:len(vals)*9]
concentration = concentration_data.iloc[:,len(vals)*8:len(vals)*9]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %%
param_name = "dead_phagocytosis_rate_NLCs"
viability = viability_data.iloc[:,len(vals)*9:len(vals)*10]
concentration = concentration_data.iloc[:,len(vals)*9:len(vals)*10]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()
